# %%
#Jack Baxter
#AI analyzer project 1

# %%
#import gcloud aiplatform 
from google.cloud import aiplatform

#import gcloud storage
from google.cloud import storage

#import langchain and vertex
import vertexai
from langchain_google_vertexai import HarmBlockThreshold, HarmCategory
from vertexai import agent_engines
from typing import Optional
from vertexai.preview import extensions
# Out:
# /Users/jackbaxter/Desktop/autoa/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
#assign project and location
aiplatform.init(project='automatedanomaly', location='us-central1')

# %%
#initialize client 
client = storage.Client()

# %%
vertexai.init(project='automatedanomaly', location='us-central1')
model = 'gemini-1.5-flash-002'

# %%
#safety settings
safety_settings = {
    HarmCategory.HARM_CATEGORY_UNSPECIFIED: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_ONLY_HIGH,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_LOW_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
}

# %%
model_kwargs = {
    "temperature": 0.5,  # Higher for creative anomaly detection
    "max_output_tokens": 2048,
    "top_p": 0.95,
    "safety_settings": safety_settings,
}

# %%
#identify and load data from bucket 
#bucketname = baxterbucket1
bucketname = 'baxterbucket1'
blob_path = 'testing.txt'

# %%
#initialize bucket and blob
bucket = client.bucket(bucketname)
blob = bucket.blob(blob_path)

# %%
#read directly into memory and print
content = blob.download_as_text()
print(content)
# Out:
# Testing my project 1 2 3.
# Testing my project 4 5 6.
